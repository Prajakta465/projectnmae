# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install -U scikit-learn
# Out:
# ...
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/breast-cancer.csv',names=['age','tyepe','age1','year','satus','r1','l1','result','final'])
df=pd.DataFrame(df1)
df
# Out:
#                age    tyepe   age1   year satus       r1          l1 result  \
# '40-49'  'premeno'  '15-19'  '0-2'  'yes'   '3'  'right'   'left_up'   'no'
# '50-59'     'ge40'  '15-19'  '0-2'   'no'   '1'  'right'   'central'   'no'
# '50-59'     'ge40'  '35-39'  '0-2'   'no'   '2'   'left'  'left_low'   'no'
# '40-49'  'premeno'  '35-39'  '0-2'  'yes'   '3'  'right'  'left_low'  'yes'
# '40-49'  'premeno'  '30-34'  '3-5'  'yes'   '2'   'left'  'right_up'   'no'
# ...            ...      ...    ...    ...   ...      ...         ...    ...
# '50-59'     'ge40'  '30-34'  '6-8'  'yes'   '2'   'left'  'left_low'   'no'
# '50-59'  'premeno'  '25-29'  '3-5'  'yes'   '2'   'left'  'left_low'  'yes'
# '30-39'  'premeno'  '30-34'  '6-8'  'yes'   '2'  'right'  'right_up'   'no'
# '50-59'  'premeno'  '15-19'  '0-2'   'no'   '2'  'right'  'left_low'   'no'
# '50-59'     'ge40'  '40-44'  '0-2'   'no'   '3'   'left'  'right_up'   'no'
#
#                           final
# ...

# %%
dff=pd.get_dummies(df,columns=['year'],drop_first=True)
dff
# Out:
#                age    tyepe   age1 satus       r1          l1 result  \
# '40-49'  'premeno'  '15-19'  '0-2'   '3'  'right'   'left_up'   'no'
# '50-59'     'ge40'  '15-19'  '0-2'   '1'  'right'   'central'   'no'
# '50-59'     'ge40'  '35-39'  '0-2'   '2'   'left'  'left_low'   'no'
# '40-49'  'premeno'  '35-39'  '0-2'   '3'  'right'  'left_low'  'yes'
# '40-49'  'premeno'  '30-34'  '3-5'   '2'   'left'  'right_up'   'no'
# ...            ...      ...    ...   ...      ...         ...    ...
# '50-59'     'ge40'  '30-34'  '6-8'   '2'   'left'  'left_low'   'no'
# '50-59'  'premeno'  '25-29'  '3-5'   '2'   'left'  'left_low'  'yes'
# '30-39'  'premeno'  '30-34'  '6-8'   '2'  'right'  'right_up'   'no'
# '50-59'  'premeno'  '15-19'  '0-2'   '2'  'right'  'left_low'   'no'
# '50-59'     'ge40'  '40-44'  '0-2'   '3'   'left'  'right_up'   'no'
#
#                           final  year_'yes'
# '40-49'     'recurrence-events'           1
# '50-59'  'no-recurrence-events'           0
# ...

# %%
dff.shape
# Out:
# (286, 9)

# %%
df.value_counts('year')
# Out:
# year
# 'no'     222
# 'yes'     56
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(df.iloc[:,0:7],df.iloc[:, -1],test_size=0.2)

# %%
x_train.head()
# Out:
#                age    tyepe    age1  year satus       r1          l1
# '30-39'  'premeno'  '30-34'   '3-5'  'no'   '3'  'right'   'left_up'
# '30-39'  'premeno'  '40-44'   '0-2'  'no'   '1'   'left'   'left_up'
# '30-39'  'premeno'  '30-34'  '9-11'  'no'   '2'  'right'   'left_up'
# '40-49'  'premeno'    '0-4'   '0-2'  'no'   '3'   'left'   'central'
# '60-69'     'ge40'  '25-29'   '0-2'  'no'   '3'  'right'  'left_low'

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(drop='first' )

# %%
x_train_new=ohe.fit_transform(x_train [['year']]).toarray()
x_train_new.shape
# Out:
# (228, 2)

# %%
x_test_new=ohe.transform(x_test[['year']]).toarray()

# %%
df3=np.hstack((x_train[['age','tyepe','age1','satus','r1','l1']].values,x_train_new))
df3.shape
# Out:
# (228, 8)

# %%
df4=pd.DataFrame(df3)

# %%
df4
# Out:
#              0        1        2    3        4           5    6    7
# 0    'premeno'  '30-34'    '3-5'  '3'  'right'   'left_up'  0.0  0.0
# 1    'premeno'  '40-44'    '0-2'  '1'   'left'   'left_up'  0.0  0.0
# 2    'premeno'  '30-34'   '9-11'  '2'  'right'   'left_up'  0.0  0.0
# 3    'premeno'    '0-4'    '0-2'  '3'   'left'   'central'  0.0  0.0
# 4       'ge40'  '25-29'    '0-2'  '3'  'right'  'left_low'  0.0  0.0
# ..         ...      ...      ...  ...      ...         ...  ...  ...
# 223     'ge40'  '20-24'  '24-26'  '3'   'left'  'left_low'  1.0  0.0
# 224  'premeno'  '20-24'    '0-2'  '1'   'left'  'left_low'  0.0  0.0
# 225  'premeno'  '15-19'    '0-2'  '2'   'left'  'left_low'  0.0  0.0
# 226     'lt40'  '15-19'    '0-2'  '2'   'left'  'left_low'  0.0  0.0
# 227     'ge40'  '45-49'    '0-2'  '1'  'right'  'right_up'  0.0  0.0
#
# [228 rows x 8 columns]
